# %%
import requests
import re
import time
import os
import shutil
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras import backend as K

class Scrapper:
    def downloadImages(url, path, pages, since=None, until=None):
        print('downloading url={0} since={1} page={2}, until={3}'.format(url, since, pages, until))
        page = requests.get(url if since is None else url + '?since=' + since)
        lines = page.text.split('\n')
        next_since = ""
        line_count = 0
        for l in lines:
            m = re.findall('href="/friends\?since=(.+?)" name="more"', l)
            if len(m) > 0:
                next_since = m[0]

            if(until is not None):
                m = re.findall('<span class="d">(.+?)</span>', l)
                if(len(m) > 0 and m[0] == until):
                    return
                
            m = re.findall('a class="lightbox".+?href="(.+?)".+?img.+?src=".+?"', l)
            if len(m) == 0:
                m = re.findall('img.+?alt="\d{4} .+?".+?src="(.+?asset.+?)"', l)
            if len(m) > 0:
                name = m[0].split("/")[-1]
                if os.path.isfile(path + '/' + name):
                    continue
                    
                image = requests.get(m[0])
                time.sleep(1)
                line_count = line_count + 1
                if image.status_code == 200:
                    with open(path + '/' + name, 'wb') as f:
                        f.write(image.content)                
                
        if line_count == 0:
            pages = pages // 2
        if len(next_since) > 0 and pages > 1:
            Scrapper.downloadImages(url, path, pages - 1, next_since, until)
            
class Predictor:
    img_width, img_height = 150, 150
    input_shape = (3, img_width, img_height) if K.image_data_format() == 'channels_first' else (img_width, img_height, 3)
    
    model = Sequential()
    model.add(Conv2D(32, (3, 3), input_shape=input_shape))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(32, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(64, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(64))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(1))
    model.add(Activation('sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
    model.load_weights('first_try.h5')
        
    def predictDir(prediction_dir):
        prediction_generator = ImageDataGenerator(rescale=1./255).flow_from_directory(
            prediction_dir,
            target_size=(Predictor.img_width, Predictor.img_height),
            batch_size=1,
            class_mode='binary')
        return Predictor.model.predict_generator(prediction_generator, steps=1)
    
    def getAllPredictions(input_dir, prediction_dir, output_dir):
        for file in os.listdir(input_dir):
            if os.path.isfile(os.path.join(input_dir, file)) and file.split(".")[-1] != 'gif':
                output_path = shutil.copy2(os.path.join(input_dir, file), prediction_dir + '/tmp')
                try:
                    prediction = Predictor.predictDir(prediction_dir)
                    if prediction[0][0] > 0.5:
                        shutil.copy2(output_path, output_dir)
                except:
                    pass
                os.remove(output_path)
# Out:
# Using TensorFlow backend.

# %%
Predictor.getAllPredictions('in', 'predict', 'out')
# Out:
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# C:\Users\marcinm\AppData\Local\Continuum\Miniconda3\envs\forkeras\lib\site-packages\PIL\TiffImagePlugin.py:709: UserWarning: Corrupt EXIF data.  Expecting to read 2 bytes but only got 0.
#   warnings.warn(str(msg))
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.
# Found 1 images belonging to 1 classes.

# %%
up_to = '08'
Scrapper.downloadImages("http://vogel.soup.io/friends", "in", 100, None, up_to)
Scrapper.downloadImages("http://bercik.soup.io/friends", "in", 100, None, up_to)
Scrapper.downloadImages("http://inzynier.soup.io/friends", "in", 100, None, up_to)
Scrapper.downloadImages("http://siostra.soup.io/friends", "in", 100, None, up_to)
Scrapper.downloadImages("http://tfu.soup.io", "in", 1, None, up_to)
Scrapper.downloadImages("http://niedobrze.soup.io", "in", 1, None, up_to)
Scrapper.downloadImages("http://ecce.soup.io/friends", "in", 100, None, up_to)
Scrapper.downloadImages("http://sucznik.soup.io/friends", "in", 100, None, up_to)
Scrapper.downloadImages("http://bumszakalaka.soup.io/friends", "in", 100, None, up_to)
Scrapper.downloadImages("http://saski.soup.io/friends", "in", 100, None, up_to)
# Out:
# downloading url=http://vogel.soup.io/friends since=None page=100, until=08
# downloading url=http://vogel.soup.io/friends since=637525305 page=99, until=08
# downloading url=http://vogel.soup.io/friends since=637494678 page=98, until=08
# downloading url=http://vogel.soup.io/friends since=637493082 page=97, until=08
# downloading url=http://vogel.soup.io/friends since=637473226 page=47, until=08
# downloading url=http://vogel.soup.io/friends since=637472763 page=22, until=08
# downloading url=http://bercik.soup.io/friends since=None page=100, until=08
# downloading url=http://bercik.soup.io/friends since=637549381 page=99, until=08
# downloading url=http://bercik.soup.io/friends since=637549181 page=98, until=08
# downloading url=http://bercik.soup.io/friends since=637548896 page=97, until=08
# downloading url=http://bercik.soup.io/friends since=637545563 page=96, until=08
# downloading url=http://bercik.soup.io/friends since=637541458 page=95, until=08
# downloading url=http://bercik.soup.io/friends since=637540782 page=94, until=08
# downloading url=http://bercik.soup.io/friends since=637540569 page=93, until=08
# downloading url=http://bercik.soup.io/friends since=637528269 page=92, until=08
# downloading url=http://bercik.soup.io/friends since=637527004 page=91, until=08
# downloading url=http://bercik.soup.io/friends since=637526598 page=90, until=08
# downloading url=http://bercik.soup.io/friends since=637526339 page=89, until=08
# downloading url=http://bercik.soup.io/friends since=637525696 page=88, until=08
# downloading url=http://bercik.soup.io/friends since=637525234 page=87, until=08
# downloading url=http://bercik.soup.io/friends since=637524899 page=86, until=08
# downloading url=http://bercik.soup.io/friends since=637524031 page=85, until=08
# downloading url=http://bercik.soup.io/friends since=637523697 page=84, until=08
# downloading url=http://bercik.soup.io/friends since=637523105 page=83, until=08
# downloading url=http://bercik.soup.io/friends since=637520967 page=82, until=08
# downloading url=http://bercik.soup.io/friends since=637518891 page=81, until=08
# downloading url=http://bercik.soup.io/friends since=637517939 page=80, until=08
# downloading url=http://bercik.soup.io/friends since=637517566 page=79, until=08
# downloading url=http://bercik.soup.io/friends since=637516991 page=78, until=08
# downloading url=http://bercik.soup.io/friends since=637516086 page=77, until=08
# downloading url=http://bercik.soup.io/friends since=637515780 page=76, until=08
# downloading url=http://bercik.soup.io/friends since=637515520 page=75, until=08
# downloading url=http://bercik.soup.io/friends since=637515267 page=74, until=08
# downloading url=http://bercik.soup.io/friends since=637514984 page=73, until=08
# downloading url=http://bercik.soup.io/friends since=637514420 page=72, until=08
# downloading url=http://bercik.soup.io/friends since=637514187 page=71, until=08
# downloading url=http://bercik.soup.io/friends since=637513065 page=70, until=08
# downloading url=http://bercik.soup.io/friends since=637512631 page=69, until=08
# downloading url=http://bercik.soup.io/friends since=637512418 page=68, until=08
# downloading url=http://bercik.soup.io/friends since=637512247 page=67, until=08
# downloading url=http://bercik.soup.io/friends since=637511920 page=66, until=08
# downloading url=http://bercik.soup.io/friends since=637511319 page=65, until=08
# downloading url=http://bercik.soup.io/friends since=637510834 page=64, until=08
# downloading url=http://bercik.soup.io/friends since=637510355 page=63, until=08
# downloading url=http://bercik.soup.io/friends since=637509903 page=62, until=08
# downloading url=http://bercik.soup.io/friends since=637508876 page=61, until=08
# downloading url=http://bercik.soup.io/friends since=637508631 page=60, until=08
# downloading url=http://bercik.soup.io/friends since=637508253 page=59, until=08
# downloading url=http://bercik.soup.io/friends since=637507755 page=58, until=08
# downloading url=http://bercik.soup.io/friends since=637505204 page=57, until=08
# downloading url=http://bercik.soup.io/friends since=637504180 page=56, until=08
# downloading url=http://bercik.soup.io/friends since=637502892 page=55, until=08
# downloading url=http://bercik.soup.io/friends since=637501437 page=54, until=08
# downloading url=http://bercik.soup.io/friends since=637499790 page=53, until=08
# downloading url=http://bercik.soup.io/friends since=637499133 page=52, until=08
# downloading url=http://bercik.soup.io/friends since=637498634 page=51, until=08
# downloading url=http://bercik.soup.io/friends since=637497780 page=50, until=08
# downloading url=http://bercik.soup.io/friends since=637497039 page=49, until=08
# downloading url=http://bercik.soup.io/friends since=637495759 page=48, until=08
# downloading url=http://bercik.soup.io/friends since=637495500 page=47, until=08
# downloading url=http://bercik.soup.io/friends since=637494686 page=46, until=08
# downloading url=http://bercik.soup.io/friends since=637494007 page=45, until=08
# downloading url=http://bercik.soup.io/friends since=637493084 page=44, until=08
# downloading url=http://bercik.soup.io/friends since=637492429 page=43, until=08
# downloading url=http://bercik.soup.io/friends since=637491722 page=42, until=08
# downloading url=http://bercik.soup.io/friends since=637491415 page=41, until=08
# downloading url=http://bercik.soup.io/friends since=637491188 page=40, until=08
# downloading url=http://bercik.soup.io/friends since=637490855 page=39, until=08
# downloading url=http://bercik.soup.io/friends since=637490391 page=38, until=08
# downloading url=http://bercik.soup.io/friends since=637489849 page=37, until=08
# downloading url=http://bercik.soup.io/friends since=637489532 page=36, until=08
# downloading url=http://bercik.soup.io/friends since=637489096 page=35, until=08
# downloading url=http://bercik.soup.io/friends since=637487725 page=16, until=08
# downloading url=http://bercik.soup.io/friends since=637486313 page=7, until=08
# downloading url=http://bercik.soup.io/friends since=637485723 page=2, until=08
# downloading url=http://inzynier.soup.io/friends since=None page=100, until=08
# downloading url=http://inzynier.soup.io/friends since=637548000 page=99, until=08
# downloading url=http://inzynier.soup.io/friends since=637546148 page=98, until=08
# downloading url=http://inzynier.soup.io/friends since=637528342 page=97, until=08
# downloading url=http://inzynier.soup.io/friends since=637526842 page=47, until=08
# downloading url=http://inzynier.soup.io/friends since=637526449 page=22, until=08
# downloading url=http://inzynier.soup.io/friends since=637525818 page=10, until=08
# downloading url=http://inzynier.soup.io/friends since=637524885 page=4, until=08
# downloading url=http://inzynier.soup.io/friends since=637518245 page=3, until=08
# downloading url=http://inzynier.soup.io/friends since=637513185 page=2, until=08
# downloading url=http://siostra.soup.io/friends since=None page=100, until=08
# downloading url=http://siostra.soup.io/friends since=637524118 page=99, until=08
# downloading url=http://siostra.soup.io/friends since=637477163 page=98, until=08
# downloading url=http://tfu.soup.io since=None page=1, until=08
# downloading url=http://niedobrze.soup.io since=None page=1, until=08
# downloading url=http://ecce.soup.io/friends since=None page=100, until=08
# downloading url=http://sucznik.soup.io/friends since=None page=100, until=08
# downloading url=http://sucznik.soup.io/friends since=637545859 page=99, until=08
# downloading url=http://sucznik.soup.io/friends since=637529382 page=98, until=08
# downloading url=http://sucznik.soup.io/friends since=637525391 page=97, until=08
# downloading url=http://sucznik.soup.io/friends since=637524192 page=96, until=08
# downloading url=http://sucznik.soup.io/friends since=637523544 page=47, until=08
# downloading url=http://sucznik.soup.io/friends since=637512255 page=46, until=08
# downloading url=http://sucznik.soup.io/friends since=637496660 page=45, until=08
# downloading url=http://sucznik.soup.io/friends since=637496038 page=21, until=08
# downloading url=http://sucznik.soup.io/friends since=637490616 page=20, until=08
# downloading url=http://sucznik.soup.io/friends since=637476229 page=9, until=08
# downloading url=http://sucznik.soup.io/friends since=637471431 page=3, until=08
# downloading url=http://bumszakalaka.soup.io/friends since=None page=100, until=08
# downloading url=http://bumszakalaka.soup.io/friends since=637523654 page=99, until=08
# downloading url=http://saski.soup.io/friends since=None page=100, until=08
# downloading url=http://saski.soup.io/friends since=637526159 page=99, until=08
# downloading url=http://saski.soup.io/friends since=637525239 page=98, until=08
# downloading url=http://saski.soup.io/friends since=637524242 page=48, until=08
# downloading url=http://saski.soup.io/friends since=637521084 page=23, until=08
# downloading url=http://saski.soup.io/friends since=637511347 page=22, until=08
# downloading url=http://saski.soup.io/friends since=637502743 page=21, until=08
# downloading url=http://saski.soup.io/friends since=637501669 page=20, until=08
# downloading url=http://saski.soup.io/friends since=637497600 page=19, until=08
# downloading url=http://saski.soup.io/friends since=637494014 page=18, until=08
# downloading url=http://saski.soup.io/friends since=637489372 page=8, until=08
# downloading url=http://saski.soup.io/friends since=637484588 page=3, until=08
